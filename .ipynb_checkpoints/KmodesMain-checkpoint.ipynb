# %%
import prepara_kmodes_df as prep
import pandas as pd
import warnings
import matplotlib.pyplot as plt
import datetime

# %%
df = prep.exec()
# Out:
# C:\Users\lucia\Tese_Marilia\CodigoIPYNB\tratamento_dados.py:110: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Munic Empr'][i] = df['Munic Empr'][i][:2]

# %%
df.head()
# Out:
#   Agente  Causador  Acidente  \
# 0                          M
# 1                          M
# 2                          M
# 4                          M
# 5                          M
#
#                                                  CBO  \
# 0  Instaladores e reparadores de linhas e cabos e...
# 1                                 Ajudantes de obras
# 2  Trabalhadores da construção civil e obras públ...
# 4            Técnicos em eletroeletrônica e fotônica
# 5  Eletricistas eletrônicos de manutenção industr...
#
#                                               CID-10  CNAE2.0 Empregador  \
# 0  Lesões, envenenamentos e algumas outras conseq...                4329
# 1  Lesões, envenenamentos e algumas outras conseq...                4213
# 2  Doenças do sistema osteomuscular e do tecido c...                4399
# 4  Lesões, envenenamentos e algumas outras conseq...                4321
# 5  Lesões, envenenamentos e algumas outras conseq...                4329
#
#    CNAE2.0 Empregador.1 Emitente CAT Espécie do benefício Filiação Segurado  \
# 0  Obras de Instalacoes   Empregador                   Pa         Empregado
# 1  Obras de Urbanizacao   Empregador                   Pa         Empregado
# 2  Servicos Especializa   Empregador                   Pa         Empregado
# 4  Instalacoes Eletrica   Empregador                   Pa         Empregado
# 5  Obras de Instalacoes   Empregador                   Pa         Empregado
#
#   Indica acidente Munic Empr     Natureza da Lesão  \
# 0             Não         43  Contusao, Esmagament
# 1             Não         31               Fratura
# 2             Não         42  Inflamacao de Articu
# 4             Não         35     Distensao, Torcao
# 5             Não         35  Amputacao ou Enuclea
#
#   Origem de Cadastramento CAT  Parte Corpo Atingida       Sexo  \
# 0                    Internet  Braco (Entre O Punho  Masculino
# 1                    Internet  Quadris (Inclusive P  Masculino
# 2                    Internet  Antebraco (Entre O P  Masculino
# 4                    Internet  Pe (Exceto Artelhos)  Masculino
# 5                    Internet                  Dedo  Masculino
#
#   Tipo do Acidente  UF Munic. Empregador  Data Acidente.1  Idade
# 0           Típico                    43                1     33
# 1           Típico                    31                1     49
# 2           Típico                    42                2     36
# 4           Típico                    35                2     44
# 5           Típico                    35                6     39

# %% [markdown]
# # Para todos os tipos de acidentes

# %%
df_categorico = df.drop(['Agente  Causador  Acidente', 'CNAE2.0 Empregador', 'CID-10', 'UF Munic. Empregador','Emitente CAT', 'Espécie do benefício', 
                         'Data Acidente.1', 'Filiação Segurado', 'Indica acidente', 'Munic Empr', 'Tipo do Acidente', 'Origem de Cadastramento CAT', 'Idade'], axis=1)
df_categorico.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 50380 entries, 0 to 52770
# Data columns (total 5 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   CBO                   50380 non-null  object
#  1   CNAE2.0 Empregador.1  50380 non-null  object
#  2   Natureza da Lesão     50380 non-null  object
#  3   Parte Corpo Atingida  50380 non-null  object
#  4   Sexo                  50380 non-null  object
# dtypes: object(5)
# memory usage: 2.3+ MB

# %%
from kmodes.kmodes import KModes

# IMPLEMENTAR
# Elbow curve to find optimal K - Demorou em torno de 5min
cost = []
K = range(5,41,5)
for num_clusters in list(K):
    kmode = KModes(n_clusters=num_clusters, init = "random", n_init = 5, verbose=1)
    kmode.fit_predict(df_categorico)
    cost.append(kmode.cost_)
# Out:
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 10474, cost: 117800.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 2, iteration: 1/100, moves: 13801, cost: 118933.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 3, iteration: 1/100, moves: 16117, cost: 119055.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 4, iteration: 1/100, moves: 16533, cost: 119253.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 5, iteration: 1/100, moves: 15775, cost: 120207.0
# Best run was number 1
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 15463, cost: 107650.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 2, iteration: 1/100, moves: 11831, cost: 108906.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 3, iteration: 1/100, moves: 11875, cost: 107876.0
# Run 3, iteration: 2/100, moves: 244, cost: 107876.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 4, iteration: 1/100, moves: 16551, cost: 110611.0
# Run 4, iteration: 2/100, moves: 5801, cost: 110611.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 5, iteration: 1/100, moves: 19959, cost: 108945.0
# Run 5, iteration: 2/100, moves: 6747, cost: 107965.0
# Run 5, iteration: 3/100, moves: 911, cost: 107965.0
# Best run was number 1
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 7607, cost: 99983.0
# Run 1, iteration: 2/100, moves: 1, cost: 99983.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 2, iteration: 1/100, moves: 12627, cost: 99945.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 3, iteration: 1/100, moves: 11970, cost: 104506.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 4, iteration: 1/100, moves: 12483, cost: 101124.0
# Run 4, iteration: 2/100, moves: 112, cost: 101124.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 5, iteration: 1/100, moves: 12976, cost: 103532.0
# Best run was number 2
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 14769, cost: 96881.0
# Run 1, iteration: 2/100, moves: 1261, cost: 96881.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 2, iteration: 1/100, moves: 19004, cost: 95674.0
# Run 2, iteration: 2/100, moves: 2807, cost: 95674.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 3, iteration: 1/100, moves: 12587, cost: 95406.0
# Run 3, iteration: 2/100, moves: 2242, cost: 95406.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 4, iteration: 1/100, moves: 14766, cost: 96540.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 5, iteration: 1/100, moves: 7788, cost: 96425.0
# Best run was number 3
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 12985, cost: 93120.0
# Run 1, iteration: 2/100, moves: 224, cost: 93120.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 2, iteration: 1/100, moves: 5822, cost: 96477.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 3, iteration: 1/100, moves: 7712, cost: 96502.0
# Run 3, iteration: 2/100, moves: 719, cost: 96502.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 4, iteration: 1/100, moves: 18355, cost: 94988.0
# Run 4, iteration: 2/100, moves: 885, cost: 94988.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 5, iteration: 1/100, moves: 12488, cost: 97177.0
# Run 5, iteration: 2/100, moves: 2608, cost: 97177.0
# Best run was number 1
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 9559, cost: 92478.0
# Run 1, iteration: 2/100, moves: 1145, cost: 92478.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 2, iteration: 1/100, moves: 15263, cost: 91665.0
# Run 2, iteration: 2/100, moves: 68, cost: 91665.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 3, iteration: 1/100, moves: 7322, cost: 90487.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 4, iteration: 1/100, moves: 8732, cost: 92308.0
# Run 4, iteration: 2/100, moves: 912, cost: 92308.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 5, iteration: 1/100, moves: 12659, cost: 91707.0
# Run 5, iteration: 2/100, moves: 499, cost: 91707.0
# Best run was number 3
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 4399, cost: 88941.0
# Run 1, iteration: 2/100, moves: 747, cost: 88823.0
# Run 1, iteration: 3/100, moves: 335, cost: 88645.0
# Run 1, iteration: 4/100, moves: 4, cost: 88645.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 2, iteration: 1/100, moves: 12001, cost: 90579.0
# Run 2, iteration: 2/100, moves: 391, cost: 90579.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 3, iteration: 1/100, moves: 13438, cost: 90276.0
# Run 3, iteration: 2/100, moves: 3694, cost: 89873.0
# Run 3, iteration: 3/100, moves: 178, cost: 89873.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 4, iteration: 1/100, moves: 10735, cost: 90346.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 5, iteration: 1/100, moves: 10192, cost: 90573.0
# Run 5, iteration: 2/100, moves: 37, cost: 90573.0
# Best run was number 1
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 15517, cost: 87681.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 2, iteration: 1/100, moves: 7853, cost: 86758.0
# Run 2, iteration: 2/100, moves: 9, cost: 86758.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 3, iteration: 1/100, moves: 12329, cost: 87429.0
# Run 3, iteration: 2/100, moves: 84, cost: 87429.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 4, iteration: 1/100, moves: 13648, cost: 86237.0
# Run 4, iteration: 2/100, moves: 260, cost: 86237.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 5, iteration: 1/100, moves: 13184, cost: 86115.0
# Best run was number 5

# %%
plt.plot(K, cost, 'bx-')
plt.xlabel('No. of clusters')
plt.ylabel('Cost')
plt.title('Elbow Method For Optimal k')
plt.grid()
plt.show()

# %% [markdown]
# ### Escolhendo o número de Clusters

# %%
n_clusters_escolhidos = 30
kmode = KModes(n_clusters=n_clusters_escolhidos, init = "random", n_init = 5, verbose=1)
kmode.fit_predict(df_categorico)
# Out:
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 14628, cost: 89906.0
# Run 1, iteration: 2/100, moves: 408, cost: 89906.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 2, iteration: 1/100, moves: 15335, cost: 89144.0
# Run 2, iteration: 2/100, moves: 3820, cost: 88894.0
# Run 2, iteration: 3/100, moves: 632, cost: 88894.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 3, iteration: 1/100, moves: 8037, cost: 91242.0
# Run 3, iteration: 2/100, moves: 2, cost: 91242.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 4, iteration: 1/100, moves: 14051, cost: 89602.0
# Run 4, iteration: 2/100, moves: 1680, cost: 89602.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 5, iteration: 1/100, moves: 10681, cost: 91167.0
# Best run was number 2
# array([ 4, 19,  7, ...,  5,  6,  1], dtype=uint16)

# %%
data_df = pd.DataFrame(kmode.cluster_centroids_)
data_df.columns = list(df_categorico.columns)

# %%
# Checando o custo do Cluster criado
print("Custo modelo: ",kmode.cost_)
# Out:
# Custo modelo:  88894.0

# %%
hoje = datetime.date.today()
nome = 'kmodes\\centroides-todos-tipos' + str(hoje) + '.csv'
data_df.to_csv(nome)

# %% [markdown]
# # Para acidentes = Típicos

# %%
df_tipicos = df.loc[df['Tipo do Acidente'] == 'Típico',:]

df_categorico = df_tipicos.drop(['Agente  Causador  Acidente', 'CNAE2.0 Empregador', 'CID-10', 'UF Munic. Empregador','Emitente CAT', 'Espécie do benefício', 
                         'Data Acidente.1', 'Filiação Segurado', 'Indica acidente', 'Munic Empr', 'Tipo do Acidente', 'Origem de Cadastramento CAT', 'Idade'], axis=1)
df_categorico.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 42838 entries, 0 to 52770
# Data columns (total 5 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   CBO                   42838 non-null  object
#  1   CNAE2.0 Empregador.1  42838 non-null  object
#  2   Natureza da Lesão     42838 non-null  object
#  3   Parte Corpo Atingida  42838 non-null  object
#  4   Sexo                  42838 non-null  object
# dtypes: object(5)
# memory usage: 2.0+ MB

# %%
# IMPLEMENTAR
# Elbow curve to find optimal K - Demorou em torno de 5min
cost = []
K = range(5,41,5)
for num_clusters in list(K):
    kmode = KModes(n_clusters=num_clusters, init = "random", n_init = 5, verbose=1)
    kmode.fit_predict(df_categorico)
    cost.append(kmode.cost_)
# Out:
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 15735, cost: 95846.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 2, iteration: 1/100, moves: 3288, cost: 98388.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 3, iteration: 1/100, moves: 12056, cost: 95922.0
# Run 3, iteration: 2/100, moves: 703, cost: 95922.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 4, iteration: 1/100, moves: 5950, cost: 95722.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 5, iteration: 1/100, moves: 10621, cost: 96466.0
# Run 5, iteration: 2/100, moves: 1864, cost: 96466.0
# Best run was number 4
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 6524, cost: 88931.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 2, iteration: 1/100, moves: 13356, cost: 89229.0
# Run 2, iteration: 2/100, moves: 4392, cost: 88519.0
# Run 2, iteration: 3/100, moves: 768, cost: 88519.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 3, iteration: 1/100, moves: 5662, cost: 95002.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 4, iteration: 1/100, moves: 13333, cost: 87410.0
# Run 4, iteration: 2/100, moves: 3247, cost: 87410.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 5, iteration: 1/100, moves: 9321, cost: 92098.0
# Best run was number 4
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 19036, cost: 83736.0
# Run 1, iteration: 2/100, moves: 905, cost: 83736.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 2, iteration: 1/100, moves: 10587, cost: 82957.0
# Run 2, iteration: 2/100, moves: 259, cost: 82957.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 3, iteration: 1/100, moves: 13462, cost: 84066.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 4, iteration: 1/100, moves: 16372, cost: 85208.0
# Run 4, iteration: 2/100, moves: 2118, cost: 85208.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 5, iteration: 1/100, moves: 9074, cost: 83724.0
# Run 5, iteration: 2/100, moves: 3200, cost: 83724.0
# Best run was number 2
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 4604, cost: 80926.0
# Run 1, iteration: 2/100, moves: 150, cost: 80926.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 2, iteration: 1/100, moves: 11129, cost: 80923.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 3, iteration: 1/100, moves: 13877, cost: 78575.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 4, iteration: 1/100, moves: 15746, cost: 78924.0
# Run 4, iteration: 2/100, moves: 872, cost: 78924.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 5, iteration: 1/100, moves: 8587, cost: 80827.0
# Run 5, iteration: 2/100, moves: 4706, cost: 80827.0
# Best run was number 3
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 6886, cost: 80438.0
# Run 1, iteration: 2/100, moves: 645, cost: 80438.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 2, iteration: 1/100, moves: 10667, cost: 78452.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 3, iteration: 1/100, moves: 12232, cost: 78491.0
# Run 3, iteration: 2/100, moves: 3238, cost: 78491.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 4, iteration: 1/100, moves: 13054, cost: 80772.0
# Run 4, iteration: 2/100, moves: 2292, cost: 80049.0
# Run 4, iteration: 3/100, moves: 1030, cost: 80049.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 5, iteration: 1/100, moves: 13341, cost: 78877.0
# Best run was number 2
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 8355, cost: 75716.0
# Run 1, iteration: 2/100, moves: 620, cost: 75716.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 2, iteration: 1/100, moves: 13304, cost: 74148.0
# Run 2, iteration: 2/100, moves: 1659, cost: 74148.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 3, iteration: 1/100, moves: 9167, cost: 75732.0
# Run 3, iteration: 2/100, moves: 12, cost: 75732.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 4, iteration: 1/100, moves: 10466, cost: 77014.0
# Run 4, iteration: 2/100, moves: 536, cost: 77014.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 5, iteration: 1/100, moves: 10072, cost: 76880.0
# Run 5, iteration: 2/100, moves: 636, cost: 76880.0
# Best run was number 2
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 15277, cost: 74022.0
# Run 1, iteration: 2/100, moves: 845, cost: 73997.0
# Run 1, iteration: 3/100, moves: 15, cost: 73997.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 2, iteration: 1/100, moves: 10373, cost: 73925.0
# Run 2, iteration: 2/100, moves: 180, cost: 73925.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 3, iteration: 1/100, moves: 5871, cost: 75070.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 4, iteration: 1/100, moves: 10001, cost: 72467.0
# Run 4, iteration: 2/100, moves: 2914, cost: 72467.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 5, iteration: 1/100, moves: 10056, cost: 74991.0
# Run 5, iteration: 2/100, moves: 1598, cost: 74825.0
# Run 5, iteration: 3/100, moves: 786, cost: 74825.0
# Best run was number 4
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 3250, cost: 71857.0
# Run 1, iteration: 2/100, moves: 70, cost: 71857.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 2, iteration: 1/100, moves: 11699, cost: 72849.0
# Run 2, iteration: 2/100, moves: 872, cost: 72849.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 3, iteration: 1/100, moves: 8172, cost: 73075.0
# Run 3, iteration: 2/100, moves: 212, cost: 73075.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 4, iteration: 1/100, moves: 8256, cost: 74506.0
# Run 4, iteration: 2/100, moves: 518, cost: 74506.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 5, iteration: 1/100, moves: 5997, cost: 72811.0
# Run 5, iteration: 2/100, moves: 164, cost: 72749.0
# Run 5, iteration: 3/100, moves: 66, cost: 72749.0
# Best run was number 1

# %%
plt.plot(K, cost, 'bx-')
plt.xlabel('No. of clusters')
plt.ylabel('Cost')
plt.title('Elbow Method For Optimal k')
plt.grid()
plt.show()

# %% [markdown]
# ### Escolhendo o número de Clusters

# %%
n_clusters_escolhidos = 20
kmode = KModes(n_clusters=n_clusters_escolhidos, init = "random", n_init = 5, verbose=1)
kmode.fit_predict(df_categorico)
# Out:
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 9438, cost: 81996.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 2, iteration: 1/100, moves: 11876, cost: 81362.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 3, iteration: 1/100, moves: 6330, cost: 80644.0
# Run 3, iteration: 2/100, moves: 5, cost: 80644.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 4, iteration: 1/100, moves: 16865, cost: 81395.0
# Run 4, iteration: 2/100, moves: 861, cost: 81395.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 5, iteration: 1/100, moves: 13555, cost: 79381.0
# Run 5, iteration: 2/100, moves: 1060, cost: 79381.0
# Best run was number 5
# array([8, 4, 0, ..., 4, 0, 3], dtype=uint16)

# %%
data_df = pd.DataFrame(kmode.cluster_centroids_)
data_df.columns = list(df_categorico.columns)

# %%
# Checando o custo do Cluster criado
print("Custo modelo: ",kmode.cost_)
# Out:
# Custo modelo:  79381.0

# %%
hoje = datetime.date.today()
nome = 'kmodes\\centroides-tipicos' + str(hoje) + '.csv'
data_df.to_csv(nome)

# %% [markdown]
# # Para acidentes = Trajeto

# %%
df_trajeto = df.loc[df['Tipo do Acidente'] == 'Trajeto',:]

df_categorico = df_trajeto.drop(['Agente  Causador  Acidente', 'CNAE2.0 Empregador', 'CID-10', 'UF Munic. Empregador','Emitente CAT', 'Espécie do benefício', 
                         'Data Acidente.1', 'Filiação Segurado', 'Indica acidente', 'Munic Empr', 'Tipo do Acidente', 'Origem de Cadastramento CAT', 'Idade'], axis=1)
df_categorico.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7127 entries, 6 to 52767
# Data columns (total 5 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   CBO                   7127 non-null   object
#  1   CNAE2.0 Empregador.1  7127 non-null   object
#  2   Natureza da Lesão     7127 non-null   object
#  3   Parte Corpo Atingida  7127 non-null   object
#  4   Sexo                  7127 non-null   object
# dtypes: object(5)
# memory usage: 334.1+ KB

# %%
# IMPLEMENTAR
# Elbow curve to find optimal K - Demorou em torno de 5min
cost = []
K = range(5,41,5)
for num_clusters in list(K):
    kmode = KModes(n_clusters=num_clusters, init = "random", n_init = 5, verbose=1)
    kmode.fit_predict(df_categorico)
    cost.append(kmode.cost_)
# Out:
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 1476, cost: 17594.0
# Run 1, iteration: 2/100, moves: 440, cost: 17594.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 2, iteration: 1/100, moves: 1189, cost: 18463.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 3, iteration: 1/100, moves: 1914, cost: 18247.0
# Run 3, iteration: 2/100, moves: 64, cost: 18247.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 4, iteration: 1/100, moves: 1746, cost: 17655.0
# Run 4, iteration: 2/100, moves: 255, cost: 17655.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 5, iteration: 1/100, moves: 1291, cost: 17708.0
# Run 5, iteration: 2/100, moves: 820, cost: 17708.0
# Best run was number 1
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 1806, cost: 16288.0
# Run 1, iteration: 2/100, moves: 222, cost: 16288.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 2, iteration: 1/100, moves: 1699, cost: 16342.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 3, iteration: 1/100, moves: 1809, cost: 16069.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 4, iteration: 1/100, moves: 1825, cost: 16179.0
# Run 4, iteration: 2/100, moves: 388, cost: 16179.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 5, iteration: 1/100, moves: 2335, cost: 16020.0
# Best run was number 5
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 1363, cost: 15213.0
# Run 1, iteration: 2/100, moves: 37, cost: 15213.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 2, iteration: 1/100, moves: 2955, cost: 15433.0
# Run 2, iteration: 2/100, moves: 50, cost: 15433.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 3, iteration: 1/100, moves: 1590, cost: 15151.0
# Run 3, iteration: 2/100, moves: 294, cost: 15151.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 4, iteration: 1/100, moves: 1611, cost: 15215.0
# Run 4, iteration: 2/100, moves: 124, cost: 15215.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 5, iteration: 1/100, moves: 1804, cost: 15525.0
# Best run was number 3
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 3117, cost: 14812.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 2, iteration: 1/100, moves: 992, cost: 15042.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 3, iteration: 1/100, moves: 2173, cost: 14168.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 4, iteration: 1/100, moves: 1673, cost: 14923.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 5, iteration: 1/100, moves: 1908, cost: 14571.0
# Best run was number 3
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 985, cost: 14161.0
# Run 1, iteration: 2/100, moves: 132, cost: 14139.0
# Run 1, iteration: 3/100, moves: 4, cost: 14139.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 2, iteration: 1/100, moves: 2302, cost: 14064.0
# Run 2, iteration: 2/100, moves: 135, cost: 14064.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 3, iteration: 1/100, moves: 1767, cost: 14163.0
# Run 3, iteration: 2/100, moves: 27, cost: 14163.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 4, iteration: 1/100, moves: 2661, cost: 14373.0
# Run 4, iteration: 2/100, moves: 218, cost: 14373.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 5, iteration: 1/100, moves: 2316, cost: 13708.0
# Run 5, iteration: 2/100, moves: 314, cost: 13708.0
# Best run was number 5
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 2170, cost: 13563.0
# Run 1, iteration: 2/100, moves: 3, cost: 13563.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 2, iteration: 1/100, moves: 1234, cost: 13915.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 3, iteration: 1/100, moves: 1495, cost: 13473.0
# Run 3, iteration: 2/100, moves: 44, cost: 13473.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 4, iteration: 1/100, moves: 1732, cost: 13571.0
# Run 4, iteration: 2/100, moves: 76, cost: 13571.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 5, iteration: 1/100, moves: 1846, cost: 13715.0
# Run 5, iteration: 2/100, moves: 78, cost: 13715.0
# Best run was number 3
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 1191, cost: 13156.0
# Run 1, iteration: 2/100, moves: 353, cost: 13156.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 2, iteration: 1/100, moves: 1432, cost: 13506.0
# Run 2, iteration: 2/100, moves: 9, cost: 13506.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 3, iteration: 1/100, moves: 1924, cost: 13187.0
# Run 3, iteration: 2/100, moves: 51, cost: 13187.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 4, iteration: 1/100, moves: 1364, cost: 13290.0
# Run 4, iteration: 2/100, moves: 62, cost: 13290.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 5, iteration: 1/100, moves: 1557, cost: 13621.0
# Best run was number 1
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 1099, cost: 13250.0
# Run 1, iteration: 2/100, moves: 71, cost: 13250.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 2, iteration: 1/100, moves: 1131, cost: 12980.0
# Run 2, iteration: 2/100, moves: 109, cost: 12980.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 3, iteration: 1/100, moves: 1661, cost: 12656.0
# Run 3, iteration: 2/100, moves: 168, cost: 12656.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 4, iteration: 1/100, moves: 1165, cost: 12836.0
# Run 4, iteration: 2/100, moves: 38, cost: 12836.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 5, iteration: 1/100, moves: 1056, cost: 13072.0
# Run 5, iteration: 2/100, moves: 19, cost: 13072.0
# Best run was number 3

# %%
plt.plot(K, cost, 'bx-')
plt.xlabel('No. of clusters')
plt.ylabel('Cost')
plt.title('Elbow Method For Optimal k')
plt.grid()
plt.show()

# %% [markdown]
# ### Escolhendo o número de Clusters

# %%
n_clusters_escolhidos = 25
kmode = KModes(n_clusters=n_clusters_escolhidos, init = "random", n_init = 5, verbose=1)
kmode.fit_predict(df_categorico)
# Out:
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 1578, cost: 13775.0
# Run 1, iteration: 2/100, moves: 20, cost: 13775.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 2, iteration: 1/100, moves: 857, cost: 14307.0
# Run 2, iteration: 2/100, moves: 615, cost: 14083.0
# Run 2, iteration: 3/100, moves: 126, cost: 14083.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 3, iteration: 1/100, moves: 895, cost: 14227.0
# Run 3, iteration: 2/100, moves: 176, cost: 14201.0
# Run 3, iteration: 3/100, moves: 4, cost: 14201.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 4, iteration: 1/100, moves: 2436, cost: 13950.0
# Run 4, iteration: 2/100, moves: 123, cost: 13950.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 5, iteration: 1/100, moves: 1504, cost: 14239.0
# Run 5, iteration: 2/100, moves: 493, cost: 14214.0
# Run 5, iteration: 3/100, moves: 20, cost: 14214.0
# Best run was number 1
# array([21, 11, 11, ...,  6, 11, 18], dtype=uint16)

# %%
data_df = pd.DataFrame(kmode.cluster_centroids_)
data_df.columns = list(df_categorico.columns)

# %%
# Checando o custo do Cluster criado
print("Custo modelo: ",kmode.cost_)
# Out:
# Custo modelo:  13775.0

# %%
hoje = datetime.date.today()
nome = 'kmodes\\centroides-trajetos' + str(hoje) + '.csv'
data_df.to_csv(nome)

# %% [markdown]
# # Para acidentes = Doenças

# %%
df_doenca = df.loc[df['Tipo do Acidente'] == 'Doença',:]

df_categorico = df_doenca.drop(['Agente  Causador  Acidente', 'CNAE2.0 Empregador', 'CID-10', 'UF Munic. Empregador','Emitente CAT', 'Espécie do benefício', 
                         'Data Acidente.1', 'Filiação Segurado', 'Indica acidente', 'Munic Empr', 'Tipo do Acidente', 'Origem de Cadastramento CAT', 'Idade'], axis=1)
df_categorico.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 415 entries, 355 to 52686
# Data columns (total 5 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   CBO                   415 non-null    object
#  1   CNAE2.0 Empregador.1  415 non-null    object
#  2   Natureza da Lesão     415 non-null    object
#  3   Parte Corpo Atingida  415 non-null    object
#  4   Sexo                  415 non-null    object
# dtypes: object(5)
# memory usage: 19.5+ KB

# %%
# IMPLEMENTAR
# Elbow curve to find optimal K - Demorou em torno de 5min
cost = []
K = range(5,41,5)
for num_clusters in list(K):
    kmode = KModes(n_clusters=num_clusters, init = "random", n_init = 5, verbose=1)
    kmode.fit_predict(df_categorico)
    cost.append(kmode.cost_)
# Out:
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 130, cost: 1017.0
# Run 1, iteration: 2/100, moves: 0, cost: 1017.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 2, iteration: 1/100, moves: 104, cost: 980.0
# Run 2, iteration: 2/100, moves: 53, cost: 960.0
# Run 2, iteration: 3/100, moves: 3, cost: 960.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 3, iteration: 1/100, moves: 121, cost: 963.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 4, iteration: 1/100, moves: 140, cost: 998.0
# Run 4, iteration: 2/100, moves: 22, cost: 998.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 5, iteration: 1/100, moves: 133, cost: 986.0
# Best run was number 2
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 121, cost: 807.0
# Run 1, iteration: 2/100, moves: 26, cost: 801.0
# Run 1, iteration: 3/100, moves: 32, cost: 801.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 2, iteration: 1/100, moves: 70, cost: 924.0
# Run 2, iteration: 2/100, moves: 12, cost: 910.0
# Run 2, iteration: 3/100, moves: 11, cost: 908.0
# Run 2, iteration: 4/100, moves: 0, cost: 908.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 3, iteration: 1/100, moves: 97, cost: 884.0
# Run 3, iteration: 2/100, moves: 41, cost: 859.0
# Run 3, iteration: 3/100, moves: 10, cost: 859.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 4, iteration: 1/100, moves: 79, cost: 948.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 5, iteration: 1/100, moves: 128, cost: 829.0
# Run 5, iteration: 2/100, moves: 1, cost: 829.0
# Best run was number 1
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 121, cost: 745.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 2, iteration: 1/100, moves: 63, cost: 815.0
# Run 2, iteration: 2/100, moves: 10, cost: 805.0
# Run 2, iteration: 3/100, moves: 9, cost: 805.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 3, iteration: 1/100, moves: 127, cost: 792.0
# Run 3, iteration: 2/100, moves: 25, cost: 786.0
# Run 3, iteration: 3/100, moves: 10, cost: 782.0
# Run 3, iteration: 4/100, moves: 0, cost: 782.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 4, iteration: 1/100, moves: 77, cost: 789.0
# Run 4, iteration: 2/100, moves: 23, cost: 789.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 5, iteration: 1/100, moves: 97, cost: 799.0
# Run 5, iteration: 2/100, moves: 9, cost: 799.0
# Best run was number 1
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 119, cost: 728.0
# Run 1, iteration: 2/100, moves: 23, cost: 728.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 2, iteration: 1/100, moves: 112, cost: 730.0
# Run 2, iteration: 2/100, moves: 34, cost: 730.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 3, iteration: 1/100, moves: 109, cost: 696.0
# Run 3, iteration: 2/100, moves: 21, cost: 694.0
# Run 3, iteration: 3/100, moves: 1, cost: 694.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 4, iteration: 1/100, moves: 131, cost: 715.0
# Run 4, iteration: 2/100, moves: 25, cost: 715.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 5, iteration: 1/100, moves: 130, cost: 713.0
# Run 5, iteration: 2/100, moves: 18, cost: 713.0
# Best run was number 3
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 46, cost: 703.0
# Run 1, iteration: 2/100, moves: 17, cost: 698.0
# Run 1, iteration: 3/100, moves: 14, cost: 698.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 2, iteration: 1/100, moves: 119, cost: 645.0
# Run 2, iteration: 2/100, moves: 8, cost: 645.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 3, iteration: 1/100, moves: 60, cost: 685.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 4, iteration: 1/100, moves: 120, cost: 684.0
# Run 4, iteration: 2/100, moves: 31, cost: 684.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 5, iteration: 1/100, moves: 114, cost: 677.0
# Run 5, iteration: 2/100, moves: 47, cost: 667.0
# Run 5, iteration: 3/100, moves: 18, cost: 667.0
# Best run was number 2
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 98, cost: 669.0
# Run 1, iteration: 2/100, moves: 14, cost: 668.0
# Run 1, iteration: 3/100, moves: 0, cost: 668.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 2, iteration: 1/100, moves: 108, cost: 650.0
# Run 2, iteration: 2/100, moves: 11, cost: 644.0
# Run 2, iteration: 3/100, moves: 4, cost: 644.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 3, iteration: 1/100, moves: 102, cost: 628.0
# Run 3, iteration: 2/100, moves: 26, cost: 626.0
# Run 3, iteration: 3/100, moves: 1, cost: 626.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 4, iteration: 1/100, moves: 60, cost: 630.0
# Run 4, iteration: 2/100, moves: 16, cost: 630.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 5, iteration: 1/100, moves: 95, cost: 660.0
# Run 5, iteration: 2/100, moves: 7, cost: 659.0
# Run 5, iteration: 3/100, moves: 1, cost: 658.0
# Run 5, iteration: 4/100, moves: 0, cost: 658.0
# Best run was number 3
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 84, cost: 621.0
# Run 1, iteration: 2/100, moves: 16, cost: 618.0
# Run 1, iteration: 3/100, moves: 5, cost: 618.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 2, iteration: 1/100, moves: 104, cost: 603.0
# Run 2, iteration: 2/100, moves: 15, cost: 603.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 3, iteration: 1/100, moves: 139, cost: 606.0
# Run 3, iteration: 2/100, moves: 25, cost: 599.0
# Run 3, iteration: 3/100, moves: 5, cost: 599.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 4, iteration: 1/100, moves: 94, cost: 603.0
# Run 4, iteration: 2/100, moves: 20, cost: 603.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 5, iteration: 1/100, moves: 97, cost: 625.0
# Run 5, iteration: 2/100, moves: 4, cost: 622.0
# Run 5, iteration: 3/100, moves: 0, cost: 622.0
# Best run was number 3
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 115, cost: 575.0
# Run 1, iteration: 2/100, moves: 18, cost: 575.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 2, iteration: 1/100, moves: 80, cost: 593.0
# Run 2, iteration: 2/100, moves: 12, cost: 589.0
# Run 2, iteration: 3/100, moves: 16, cost: 582.0
# Run 2, iteration: 4/100, moves: 6, cost: 582.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 3, iteration: 1/100, moves: 82, cost: 590.0
# Run 3, iteration: 2/100, moves: 20, cost: 586.0
# Run 3, iteration: 3/100, moves: 0, cost: 586.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 4, iteration: 1/100, moves: 54, cost: 615.0
# Run 4, iteration: 2/100, moves: 24, cost: 610.0
# Run 4, iteration: 3/100, moves: 6, cost: 610.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 5, iteration: 1/100, moves: 89, cost: 571.0
# Run 5, iteration: 2/100, moves: 5, cost: 571.0
# Best run was number 5

# %%
plt.plot(K, cost, 'bx-')
plt.xlabel('No. of clusters')
plt.ylabel('Cost')
plt.title('Elbow Method For Optimal k')
plt.grid()
plt.show()

# %% [markdown]
# ### Escolhendo o número de Clusters

# %%
n_clusters_escolhidos = 25
kmode = KModes(n_clusters=n_clusters_escolhidos, init = "random", n_init = 5, verbose=1)
kmode.fit_predict(df_categorico)
# Out:
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 67, cost: 661.0
# Run 1, iteration: 2/100, moves: 10, cost: 661.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 2, iteration: 1/100, moves: 60, cost: 702.0
# Run 2, iteration: 2/100, moves: 3, cost: 700.0
# Run 2, iteration: 3/100, moves: 0, cost: 700.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 3, iteration: 1/100, moves: 94, cost: 692.0
# Run 3, iteration: 2/100, moves: 1, cost: 692.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 4, iteration: 1/100, moves: 91, cost: 697.0
# Run 4, iteration: 2/100, moves: 28, cost: 687.0
# Run 4, iteration: 3/100, moves: 21, cost: 678.0
# Run 4, iteration: 4/100, moves: 2, cost: 678.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 5, iteration: 1/100, moves: 131, cost: 739.0
# Run 5, iteration: 2/100, moves: 41, cost: 739.0
# Best run was number 1
# array([ 7,  6,  3, 19, 17, 10,  8, 19,  0, 11, 11,  0,  0, 19,  1,  1, 11,
#         0, 20, 24,  6,  8, 17, 16,  9,  0,  1,  0,  3, 11,  6,  0,  6,  8,
#         3,  6, 22,  7,  3, 19, 19,  0,  6,  4,  4,  0,  6,  0,  0, 19, 24,
#         0, 10, 19,  8,  3,  0,  5,  8,  0,  0,  6, 22,  5,  3, 17, 17,  0,
#         8, 20, 19,  1, 16, 14, 11, 11, 11, 11, 11, 11, 11, 11, 11, 11, 11,
#        11, 11, 11, 11, 11, 11, 11, 11, 11, 11, 11, 19, 16,  1,  0,  0,  0,
#         7, 10,  6,  0,  1,  0,  0,  7,  8,  8, 16, 16,  0,  0,  0,  2,  3,
#         0, 12, 16,  5, 20, 16, 15, 15, 15, 15,  0,  0,  5, 16,  5,  7, 16,
#        19,  0,  1, 20,  0,  0,  9, 16,  0, 16,  8,  1,  0, 24, 19,  0, 19,
#         6,  3,  3, 19, 11,  5,  5, 19, 19,  7,  0,  0, 19,  5,  0, 16, 16,
#         9,  4, 23, 16,  0, 22, 22, 22, 12,  4,  6,  1, 22, 22,  6,  5,  0,
#        10, 10,  4,  0, 16,  1,  0,  1,  0,  3,  3,  0,  5,  1, 10,  6,  3,
#         0, 10,  3,  5,  8,  2,  7,  0,  5,  3,  1,  4,  2,  8, 10,  6,  0,
#        19,  0,  6, 22,  6,  3,  3,  1,  2, 15, 15, 15, 15, 15, 15, 15, 15,
#        15,  6, 15, 15, 15,  3,  5,  0,  6,  6,  6,  6,  6,  6,  6,  6,  6,
#         3,  0, 19,  3,  3,  0,  6, 16, 16,  0,  8, 12, 12,  0,  3,  0,  4,
#        17, 12, 16,  1, 15,  0,  0,  6,  0,  0, 19,  3,  4, 11, 16, 18,  1,
#         0,  5,  0,  1,  3,  4,  1,  3, 14,  0,  1, 13, 16,  1, 14,  3,  6,
#         0,  8, 19, 12,  5,  4,  0,  8,  4,  0,  1,  0, 11,  0, 19,  0,  1,
#         0, 21,  9, 21,  6, 21,  8,  6,  6,  7,  0,  4, 11,  0,  1, 19,  3,
#         3, 17, 22,  9, 21,  8,  0,  0,  3, 24,  1,  2,  7,  6, 21, 12,  2,
#         1,  2, 21, 21, 21,  7,  0,  3,  5,  5, 21,  0,  2, 15, 19, 21,  1,
#        21,  4, 15,  9, 15,  1, 10,  7,  7,  7,  7,  6,  3, 15, 19,  1, 16,
#         0,  0,  7,  0,  2,  0,  0,  2, 19,  0,  0,  0,  0,  8,  0,  5,  0,
#         8,  7, 14, 14,  0,  2, 21], dtype=uint16)

# %%
data_df = pd.DataFrame(kmode.cluster_centroids_)
data_df.columns = list(df_categorico.columns)

# %%
# Checando o custo do Cluster criado
print("Custo modelo: ",kmode.cost_)
# Out:
# Custo modelo:  661.0

# %%
hoje = datetime.date.today()
nome = 'kmodes\\centroides-doencas' + str(hoje) + '.csv'
data_df.to_csv(nome)

# %% [markdown]
# ## Para acidentes = Mortes

# %%
df_morte = df.loc[df['Indica acidente'] == 'Sim',:]

df_categorico = df_morte.drop(['Agente  Causador  Acidente', 'CNAE2.0 Empregador', 'CID-10', 'UF Munic. Empregador','Emitente CAT', 'Espécie do benefício', 
                         'Data Acidente.1', 'Filiação Segurado', 'Indica acidente', 'Munic Empr', 'Tipo do Acidente', 'Origem de Cadastramento CAT', 'Idade'], axis=1)
df_categorico.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 378 entries, 58 to 52769
# Data columns (total 5 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   CBO                   378 non-null    object
#  1   CNAE2.0 Empregador.1  378 non-null    object
#  2   Natureza da Lesão     378 non-null    object
#  3   Parte Corpo Atingida  378 non-null    object
#  4   Sexo                  378 non-null    object
# dtypes: object(5)
# memory usage: 17.7+ KB

# %%
# IMPLEMENTAR
# Elbow curve to find optimal K - Demorou em torno de 5min
cost = []
K = range(5,41,3)
for num_clusters in list(K):
    kmode = KModes(n_clusters=num_clusters, init = "random", n_init = 5, verbose=1)
    kmode.fit_predict(df_categorico)
    cost.append(kmode.cost_)
# Out:
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 162, cost: 806.0
# Run 1, iteration: 2/100, moves: 62, cost: 795.0
# Run 1, iteration: 3/100, moves: 7, cost: 795.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 2, iteration: 1/100, moves: 93, cost: 816.0
# Run 2, iteration: 2/100, moves: 16, cost: 791.0
# Run 2, iteration: 3/100, moves: 20, cost: 791.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 3, iteration: 1/100, moves: 98, cost: 809.0
# Run 3, iteration: 2/100, moves: 6, cost: 809.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 4, iteration: 1/100, moves: 121, cost: 802.0
# Run 4, iteration: 2/100, moves: 13, cost: 802.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 5, iteration: 1/100, moves: 96, cost: 833.0
# Run 5, iteration: 2/100, moves: 7, cost: 833.0
# Best run was number 2
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 119, cost: 736.0
# Run 1, iteration: 2/100, moves: 14, cost: 736.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 2, iteration: 1/100, moves: 103, cost: 750.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 3, iteration: 1/100, moves: 52, cost: 753.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 4, iteration: 1/100, moves: 169, cost: 762.0
# Run 4, iteration: 2/100, moves: 10, cost: 762.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 5, iteration: 1/100, moves: 43, cost: 799.0
# Run 5, iteration: 2/100, moves: 0, cost: 799.0
# Best run was number 1
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 140, cost: 691.0
# Run 1, iteration: 2/100, moves: 18, cost: 691.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 2, iteration: 1/100, moves: 87, cost: 730.0
# Run 2, iteration: 2/100, moves: 15, cost: 730.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 3, iteration: 1/100, moves: 86, cost: 724.0
# Run 3, iteration: 2/100, moves: 25, cost: 724.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 4, iteration: 1/100, moves: 147, cost: 691.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 5, iteration: 1/100, moves: 154, cost: 696.0
# Run 5, iteration: 2/100, moves: 5, cost: 696.0
# Best run was number 1
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 121, cost: 647.0
# Run 1, iteration: 2/100, moves: 4, cost: 645.0
# Run 1, iteration: 3/100, moves: 1, cost: 645.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 2, iteration: 1/100, moves: 87, cost: 639.0
# Run 2, iteration: 2/100, moves: 18, cost: 639.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 3, iteration: 1/100, moves: 114, cost: 657.0
# Run 3, iteration: 2/100, moves: 17, cost: 654.0
# Run 3, iteration: 3/100, moves: 0, cost: 654.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 4, iteration: 1/100, moves: 119, cost: 656.0
# Run 4, iteration: 2/100, moves: 7, cost: 656.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 5, iteration: 1/100, moves: 78, cost: 636.0
# Run 5, iteration: 2/100, moves: 8, cost: 636.0
# Best run was number 5
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 118, cost: 631.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 2, iteration: 1/100, moves: 100, cost: 636.0
# Run 2, iteration: 2/100, moves: 12, cost: 636.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 3, iteration: 1/100, moves: 93, cost: 619.0
# Run 3, iteration: 2/100, moves: 67, cost: 605.0
# Run 3, iteration: 3/100, moves: 13, cost: 605.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 4, iteration: 1/100, moves: 62, cost: 661.0
# Run 4, iteration: 2/100, moves: 22, cost: 650.0
# Run 4, iteration: 3/100, moves: 1, cost: 650.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 5, iteration: 1/100, moves: 92, cost: 598.0
# Run 5, iteration: 2/100, moves: 24, cost: 598.0
# Best run was number 5
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 118, cost: 595.0
# Run 1, iteration: 2/100, moves: 11, cost: 589.0
# Run 1, iteration: 3/100, moves: 2, cost: 589.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 2, iteration: 1/100, moves: 155, cost: 591.0
# Run 2, iteration: 2/100, moves: 8, cost: 590.0
# Run 2, iteration: 3/100, moves: 1, cost: 590.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 3, iteration: 1/100, moves: 72, cost: 615.0
# Run 3, iteration: 2/100, moves: 59, cost: 604.0
# Run 3, iteration: 3/100, moves: 16, cost: 604.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 4, iteration: 1/100, moves: 88, cost: 614.0
# Run 4, iteration: 2/100, moves: 23, cost: 614.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 5, iteration: 1/100, moves: 117, cost: 594.0
# Run 5, iteration: 2/100, moves: 5, cost: 594.0
# Best run was number 1
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 52, cost: 580.0
# Run 1, iteration: 2/100, moves: 11, cost: 580.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 2, iteration: 1/100, moves: 53, cost: 583.0
# Run 2, iteration: 2/100, moves: 1, cost: 582.0
# Run 2, iteration: 3/100, moves: 0, cost: 582.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 3, iteration: 1/100, moves: 75, cost: 585.0
# Run 3, iteration: 2/100, moves: 22, cost: 578.0
# Run 3, iteration: 3/100, moves: 1, cost: 578.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 4, iteration: 1/100, moves: 137, cost: 563.0
# Run 4, iteration: 2/100, moves: 16, cost: 560.0
# Run 4, iteration: 3/100, moves: 3, cost: 560.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 5, iteration: 1/100, moves: 96, cost: 576.0
# Run 5, iteration: 2/100, moves: 14, cost: 576.0
# Best run was number 4
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 119, cost: 557.0
# Run 1, iteration: 2/100, moves: 17, cost: 557.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 2, iteration: 1/100, moves: 71, cost: 566.0
# Run 2, iteration: 2/100, moves: 6, cost: 566.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 3, iteration: 1/100, moves: 123, cost: 547.0
# Run 3, iteration: 2/100, moves: 26, cost: 542.0
# Run 3, iteration: 3/100, moves: 15, cost: 542.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 4, iteration: 1/100, moves: 71, cost: 569.0
# Run 4, iteration: 2/100, moves: 14, cost: 569.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 5, iteration: 1/100, moves: 45, cost: 563.0
# Run 5, iteration: 2/100, moves: 7, cost: 563.0
# Best run was number 3
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 83, cost: 531.0
# Run 1, iteration: 2/100, moves: 8, cost: 531.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 2, iteration: 1/100, moves: 96, cost: 558.0
# Run 2, iteration: 2/100, moves: 4, cost: 558.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 3, iteration: 1/100, moves: 50, cost: 552.0
# Run 3, iteration: 2/100, moves: 7, cost: 552.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 4, iteration: 1/100, moves: 125, cost: 568.0
# Run 4, iteration: 2/100, moves: 19, cost: 567.0
# Run 4, iteration: 3/100, moves: 0, cost: 567.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 5, iteration: 1/100, moves: 92, cost: 559.0
# Run 5, iteration: 2/100, moves: 6, cost: 559.0
# Best run was number 1
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 84, cost: 546.0
# Run 1, iteration: 2/100, moves: 8, cost: 545.0
# Run 1, iteration: 3/100, moves: 0, cost: 545.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 2, iteration: 1/100, moves: 73, cost: 567.0
# Run 2, iteration: 2/100, moves: 7, cost: 567.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 3, iteration: 1/100, moves: 74, cost: 526.0
# Run 3, iteration: 2/100, moves: 3, cost: 526.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 4, iteration: 1/100, moves: 126, cost: 528.0
# Run 4, iteration: 2/100, moves: 32, cost: 527.0
# Run 4, iteration: 3/100, moves: 0, cost: 527.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 5, iteration: 1/100, moves: 129, cost: 529.0
# Run 5, iteration: 2/100, moves: 9, cost: 529.0
# Best run was number 3
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 79, cost: 516.0
# Run 1, iteration: 2/100, moves: 16, cost: 516.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 2, iteration: 1/100, moves: 57, cost: 515.0
# Run 2, iteration: 2/100, moves: 2, cost: 515.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 3, iteration: 1/100, moves: 43, cost: 549.0
# Run 3, iteration: 2/100, moves: 4, cost: 549.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 4, iteration: 1/100, moves: 116, cost: 503.0
# Run 4, iteration: 2/100, moves: 38, cost: 496.0
# Run 4, iteration: 3/100, moves: 10, cost: 496.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 5, iteration: 1/100, moves: 72, cost: 507.0
# Run 5, iteration: 2/100, moves: 1, cost: 507.0
# Best run was number 4
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 76, cost: 482.0
# Run 1, iteration: 2/100, moves: 7, cost: 482.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 2, iteration: 1/100, moves: 55, cost: 498.0
# Run 2, iteration: 2/100, moves: 11, cost: 498.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 3, iteration: 1/100, moves: 87, cost: 505.0
# Run 3, iteration: 2/100, moves: 1, cost: 505.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 4, iteration: 1/100, moves: 63, cost: 525.0
# Run 4, iteration: 2/100, moves: 4, cost: 525.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 5, iteration: 1/100, moves: 39, cost: 513.0
# Run 5, iteration: 2/100, moves: 0, cost: 513.0
# Best run was number 1

# %%
plt.plot(K, cost, 'bx-')
plt.xlabel('No. of clusters')
plt.ylabel('Cost')
plt.title('Elbow Method For Optimal k')
plt.grid()
plt.show()

# %% [markdown]
# ### Escolhendo o número de Clusters

# %%
n_clusters_escolhidos = 28
kmode = KModes(n_clusters=n_clusters_escolhidos, init = "random", n_init = 5, verbose=1)
kmode.fit_predict(df_categorico)
# Out:
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 44, cost: 578.0
# Run 1, iteration: 2/100, moves: 0, cost: 578.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 2, iteration: 1/100, moves: 51, cost: 566.0
# Run 2, iteration: 2/100, moves: 13, cost: 566.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 3, iteration: 1/100, moves: 46, cost: 571.0
# Run 3, iteration: 2/100, moves: 1, cost: 571.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 4, iteration: 1/100, moves: 59, cost: 586.0
# Run 4, iteration: 2/100, moves: 1, cost: 586.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 5, iteration: 1/100, moves: 76, cost: 555.0
# Run 5, iteration: 2/100, moves: 30, cost: 554.0
# Run 5, iteration: 3/100, moves: 1, cost: 554.0
# Best run was number 5
# array([11,  2,  4, 21,  3, 18, 13,  0, 26,  3,  8, 12, 26, 17,  0,  3,  2,
#        11,  0, 19,  2,  6,  5,  1, 22,  5,  0,  7,  8,  5,  1,  0,  2,  1,
#        15,  2,  8,  3,  1,  0,  0,  3,  5, 19,  2, 11, 21,  0,  0, 15,  5,
#        13, 27,  3, 22, 26,  5,  3,  1, 27, 27,  0,  2,  2,  0,  2,  4,  0,
#         0, 18,  7,  2, 18, 18,  0,  2,  7, 20,  5, 10, 13,  7,  7,  7, 11,
#         3,  0,  3,  2,  3,  2,  0, 15, 21, 26, 24,  0,  1,  0, 12, 12, 12,
#        26,  0,  2, 26, 12,  0,  0, 26,  1,  7, 19,  5,  5, 15, 15, 15, 11,
#        24, 12,  1,  2,  2, 18,  0,  9,  1,  8,  2,  5, 12,  5,  8, 21,  8,
#         1,  8,  1, 14,  1,  9, 15,  2,  6,  1, 12,  0,  1, 23,  2, 12,  2,
#         3,  0, 24,  2,  0,  0,  1, 11,  5,  5,  1,  2,  2, 26,  9, 12, 27,
#         7,  9,  9, 22, 24,  2,  0,  0,  5,  0,  2,  7,  0,  2,  3,  8,  1,
#         5,  0,  0, 10,  4,  7,  2,  1,  0,  1,  9,  1, 10,  0, 11,  2,  2,
#         5,  7,  0,  2,  6,  9,  8,  2,  7,  2,  2,  4,  4, 24,  2, 26,  5,
#         0,  5,  5,  8, 13, 23, 11,  2,  3, 16,  2,  0,  8,  3, 19,  0, 21,
#        23, 13,  6, 12,  2, 21,  2,  0,  2,  8,  2, 23,  2,  4,  3,  0, 26,
#        15,  3,  8,  2,  3,  0, 23,  7,  2,  6, 12,  8, 26,  5,  6,  5,  1,
#         8, 11,  8,  0,  5,  3,  3,  5, 24,  2,  2,  5,  3, 23,  9, 23,  1,
#        11,  2,  2, 13,  8,  5,  1,  2, 11,  0,  8,  8,  8, 10,  2, 26,  1,
#         0,  6,  0,  1, 26, 11,  0,  2, 10, 19, 10,  2,  5, 24,  0,  5,  5,
#         5,  2,  8,  3,  1,  0,  5, 24, 20,  2,  9,  8,  4,  0, 15,  5,  0,
#         2,  2, 11,  2,  5,  4, 23,  2,  2, 14,  0,  0, 23,  1,  2,  0, 11,
#         2, 25,  4, 21,  4,  8, 23, 19,  2,  0,  3,  2,  5,  4,  6,  2, 15,
#         0, 15, 26,  4], dtype=uint16)

# %%
data_df = pd.DataFrame(kmode.cluster_centroids_)
data_df.columns = list(df_categorico.columns)

# %%
# Checando o custo do Cluster criado
print("Custo modelo: ",kmode.cost_)
# Out:
# Custo modelo:  554.0

# %%
hoje = datetime.date.today()
nome = 'kmodes\\centroides-mortes' + str(hoje) + '.csv'
data_df.to_csv(nome)
